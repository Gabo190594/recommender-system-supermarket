# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabo190594/recommender-system-supermarket/blob/main/notebooks/01_data_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Gabo190594/recommender-system-supermarket.git
# Out:
# Cloning into 'recommender-system-supermarket'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 30 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 11.89 KiB | 11.89 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd recommender-system-supermarket
# !ls data_generation
# !python data_generation/generate_data.py
# Out:
# /content/recommender-system-supermarket/recommender-system-supermarket
# generate_data.py
# ✅ Data sintética generada en data/raw/

# %%
# !ls data/raw
import pandas as pd

users = pd.read_csv("data/raw/users.csv")
products = pd.read_csv("data/raw/products.csv")
interactions = pd.read_csv("data/raw/interactions.csv")
ratings = pd.read_csv("data/raw/ratings.csv")

print(users.shape)
print(products.shape)
print(interactions.shape)
print(ratings.shape)
# Out:
# interactions.csv  products.csv	ratings.csv  social_links.csv  users.csv
# (500, 3)
# (800, 3)
# (15000, 5)
# (4000, 3)
