# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabo190594/recommender-system-supermarket/blob/main/notebooks01_data_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python data_generation/generate_data.py
# Out:
# python3: can't open file '/content/data_generation/generate_data.py': [Errno 2] No such file or directory
